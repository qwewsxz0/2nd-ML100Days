# %% [markdown]
# # 作業一
# ## 題目：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# ## 1. 你選的這組資料為何重要
# ## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ## 3. 蒐集而來的資料型態為何
# ## 4. 這組資料想解決的問題如何評估

# %% [markdown]
# ## 挑選競賽如下：
# ### Two Sigma: Using News to Predict Stock Movements

# %% [markdown]
# ### 1.	你選的這組資料為何重要?
#     由於新聞的訊息與股票的關聯是大家都知曉的，但是如何由新聞的訊息來推斷股票的漲跌，其實際的情況相當的複雜，透漏著大量的"運氣”成分，即便是擁有相當長經驗的操盤手，在做許多決定時都不得不拋開課本既有的認知，做豪賭一把，成王敗寇。顧個人認為能夠瞭解新聞對於股票的預測的情形是相當的重要，可以不必再依賴所謂的命運與經驗，而是能夠更客觀的來去做決定，也可以用於國家競技上的制定以及國與國之間外交的手段。

# %% [markdown]
# ### 2.	資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     Market data provided by Intrinio.
# ![Market%20data%20provided%20by%20Intrinio..png](attachment:Market%20data%20provided%20by%20Intrinio..png)
#
#     News data provided by Thomson Reuters. Copyright ©, Thomson Reuters, 2017.
# ![Thomson.png](attachment:Thomson.png)

# %% [markdown]
# ### 3. 蒐集而來的資料型態為何
# ### marketdata_sample.csv
# Date  time
# String  assetCode
# String  assetName
# Decimal  universe
# Decimal  volume
# Decimal  close
# Decimal  open
# Decimal  returnsClosePrevRaw1
# Decimal  returnsOpenPrevRaw1
# UUID  returnsClosePrevMktres1
# UUID  returnsOpenPrevMktres1
# Decimal  returnsClosePrevRaw10
# Decimal  returnsOpenPrevRaw10
# UUID  returnsClosePrevMktres10
# UUID  returnsOpenPrevMktres10
# Decimal  returnsOpenNextMktres10
#
# ### news_sample.csv
# Date time
# Datesource Timestamp
# Date firstCreated
# String sourceId
# String headline
# Integer urgency
# Integer takeSequence
# String provider
# String subjects
# String audiences
# Integer bodySize
# Integer companyCount
# String headlineTag
# Boolean marketCommentary
# Integer sentenceCount
# Integer wordCount
# String assetCodes
# String assetName
# Integer firstMentionSentence
# Decimal relevance
# Integer sentimentClass
# Decimal sentimentNegative
# Decimal sentimentNeutral
# Decimal sentimentPositive
# Integer sentimentWordCount
# Integer noveltyCount12H
# Integer noveltyCount24H
# Integer noveltyCount3D
# Integer noveltyCount5D
# Integer noveltyCount7D
# Integer volumeCounts12H
# Integer volumeCounts24H
# Integer volumeCounts3D
# Integer volumeCounts5D
# Integer volumeCounts7D

# %% [markdown]
# ### 4.這組資料想解決的問題如何評估
# * 涵義上評估
#     資料無法下載New entrants are currently prohibited. You must wait until after the deadline (3 months) to download the data or submit.，無法得知真實給的數據量，不過做預測的問題很重要的重點在於data與要預測的結果在其領域特性上是否make sense，以目前此競賽的題目來說，給的維度是相當完備，可以從News的資料看出來，常常股票的場蝶取決於一群剛看到新聞的民眾，故涵義上是符合的。
#
# * 維度上衡量
#     這裡的資料有35個維度來預測16個維度，直覺上也是符合意義的，否則以低維度預測高維度本身會有資訊量不足的問題。

# %% [markdown]
# # 作業2：
# ## 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ## 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ## 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# ## 3. 蒐集而來的資料型態為何
# ## 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ## 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 業績提升定義：總體的年營業額，拿過去3年的資料取平均當作基準，與之比較。
# 我的假設：載客次數像是WSS的訊號，每天會有週期性的變化，沒年因應節日也會有類似的分布趨勢，要達成總體營業額提升，不外乎要減少量的閒置時間，故在非節日尖峰時間，可以用促銷的方式提供包車服務，進而降低空車率，促進車子皆有其所用，客戶有其優惠，車子租的出去，錢進的來，台灣發大財。

# %% [markdown]
# ## 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# (1)載客次數：收費計時器自動記錄
# (2)載客時間：收費計時器自動記錄
# (3)載到客戶的時間點：收費計時器自動記錄
# (4)地區路段：搭配導航系統做紀錄
# (5)包車次數：收費計時器自動記錄
# (6)包車時間：收費計時器自動記錄
# (7)包車的時間點：收費計時器自動記錄

# %% [markdown]
# ## 3. 蒐集而來的資料型態為何
# (1)載客次數：整數(次)
# (2)載客時間：整數(秒)
# (3)再到客戶的時間點：日期(date) 時間(time)
# (4)地區路段：依區段編碼後的數字
# (5)包車次數：整數(次)
# (6)包車時間：整數(秒)
# (7)包車的時間點：日期(date) 時間(time)

# %% [markdown]
# ## 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# (1)由資料(1)~(3)來觀察周期性的變化為何，搭配地點(4)後做出可能空車時段對照表，將近3年的資料作分析，這明顯的可以知道是否有車輛閒置的分析。
# (2)由(5)~(7)觀察週期性的變化，與結晶應該也有部分正相關，但還不算多。
# (3)嘗試將(1)~(3)與(5)~(7)的資料做線性組合，搭配出不同時間應該要做多少的資源分配以達到更好的出租效果

# %% [markdown]
# # 作業3：

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

#MAE = mean_absolute_error(y, y_hat)
#print("The Mean absolute error is %.3f" % (MAE))

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum((y - yp)*(y - yp)) / len(y)
    return mse

#MSE = mean_squared_error(y, y_hat)
#print("The Mean absolute error is %.3f" % (MSE))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 221.822
# The Mean absolute error is 12.224
